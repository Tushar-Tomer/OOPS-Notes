# %% [markdown]
# ## Object Oriented programming

# %% [markdown]
# Object-oriented programming is a **programming paradigm** that provides a means of structuring programs so that properties and behaviours are bundled into individual objects.
#
# For instance, an object could represent a person with properties like a name, age, and address and behaviours such as walking, talking, breathing, and running. Or it could represent an email with properties like a recipient list, subject, and body and behaviours like adding attachments and sending.
#
# Python is an object-oriented programming language. Almost everything in Python is an object, with its properties and methods.

# %% [markdown]
# ### Why to Choose ObjectOriented Programming?
# Python was designed with an object-oriented approach. OOP offers the following advantages:
# - Provides a clear program structure, which makes it easy to map real world problems
# and their solutions.
#
#
# - Facilitates easy maintenance and modification of existing code.
#
#
# - Enhances program modularity because each object exists independently and new
# features can be added easily without disturbing the existing ones.
#
# -  Presents a good framework for code libraries where supplied components can be
# easily adapted and modified by the programmer.
#
#
# -  Imparts code reusability(creating neat and reusable code instead of a redundant one.)

# %% [markdown]
# ### Procedural vs. Object Oriented Programming
# Procedural based programming is derived from structural programming based on the
# concepts of functions/procedure/routines. It is easy to access and change the data in
# procedural oriented programming. On the other hand, Object Oriented Programming
# (OOP) allows decomposition of a problem into a number of units called objects and then
# build the data and functions around these objects. It emphasis more on the data than
# procedure or functions. Also in OOP, data is hidden and cannot be accessed by external
# procedure.

# %% [markdown]
# ![procedural_oops.JPG](attachment:procedural_oops.JPG)

# %% [markdown]
# ### here we create user defined data type

# %% [markdown]
# ### Principlesof Object Oriented Programming
# Object Oriented Programming (OOP) is based on the concept of objects rather than
# actions, and data rather than logic.
#
#
# #### Four pillars of oops
#
# - encapsulation
# - Inheritenace
# - polymorphism
# - abstarction

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# ### class can have multiple object

# %% [markdown]
# ## Class-:
#
#
# A class is a collection of objects or you can say it is a
# blueprint of objects defining the common attributes and
# behavior.
#
# blueprint means how your objects looks??
#
#
#
#
#
# A straight forward answer to this question is- A class is a collection of objects. Unlike the primitive data structures, classes are data structures that the user defines. They make the code more manageable.

# %%
## class name is pascal code

# %% [markdown]
# ### syntax:
# class class_name:
#
#       class body

# %%
class Car:
    pass

# %% [markdown]
# ### blue print of class Animal : binding of data and methods into single unit

# %%
class Animal:
    country="india"
    def __init__(abc,color1,category1,age1,name1):
        print(" i am in constructor")
        abc.color=color1
        abc.category=category1
        abc.age=age1
        abc.name=name1
        print(id(abc))
    def sleep(abc):
        print(abc.name,"is sleeping ")
    def display(abc):
        print("my name is ",abc.name)
        print("my color is ",abc.color)
        print("my age is ",abc.age)
        print("my catrgory is",abc.category)

# %%
tiger=Animal("brown","wild",5,"sheru")# paremeterized
#tiger.display()
print(id(tiger))
lion=Animal("black","wild",7,"shersingh")
print(id(lion))
lion.name="pikachu"
lion.display()
# Out:
#  i am in constructor
# 1448648155584
# 1448648155584
#  i am in constructor
# 1448648156928
# 1448648156928
# my name is  pikachu
# my color is  black
# my age is  7
# my catrgory is wild

# %%
lion=Animal("black","wild",7,"shersingh")
lion.display()
print(lion.color)
print(lion.name)
# Out:
# my name is  shersingh
# my color is  black
# my age is  7
# my catrgory is wild
# black
# shersingh

# %%
class Animal:  ## pascalname 
    country="india"  ## class variable
    def __init__(self,color,category,age):  ## magic method(in built methods) which triggered automatically/special method(constructor)
        self.color=color ## we can give any name instead of self. 
        self.category=category  ## instance variable
        self.age=age
        print(" i am in constructor")
    def display(self):
        print("my color is ",self.color)
        print("my category is ",self.category)
        print("my age is ",self.age)

# %% [raw]
# for i in range(1,5):
#     n=input("enter the name")
#     a=input("enter the age")
#     c=input("enter the color")
#     ce=input("enter the category")
#     x1=Animal(c,ce,a,n)
#     print(x1.display())

# %% [markdown]
# ## object creation

# %%
tiger=Animal() ## instantiation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 tiger=Animal()
#
# NameError: name 'Animal' is not defined

# %%
tiger=Animal("brown","wild",18) ## tiger is object
type(tiger)
# Out:
#  i am in constructor
# __main__.Animal

# %%
id(tiger)
# Out:
# 2714828462688

# %%
## as we create object constructor is called automatically ,

# %%
hen=Animal("white","Farm",5)
hen
# Out:
#  i am in constructor

# %%
## How to access the properties and methods :  using OBJECT

# %%
tiger.display()
# Out:
# my color is  brown
# my category is  wild
# my age is  18

# %%
tiger.age
# Out:
# 18

# %%
tiger.category
# Out:
# 'wild'

# %%
Animal.country  ## Access class vraible
# Out:
# 'india'

# %%
## what is __init__ ? What is its  utility

# %% [markdown]
# ####  How to Define class

# %%
class Student:  ## class name pascalname
    studentsclass="A"
    def __init__(self,name,age): ### constructor magic  methods 
        self.name=name   ### instance variable
        self.age=age     ### instamce variable
    def get_age(self):## methods name should be in snake case
        print(self.age)

# %% [markdown]
# ## How to create object

# %%
s1=Student("priya",20)
s2=Student("riya",23)
s1.get_age()
s2.get_age()
# Out:
# 20
# 23

# %%
class Car:
    car_type = "Sedan" 
    def __init__(self,color,mileage,maxspeed):
        self.color = color #instance attribute
        self.mileage = mileage
        self.maxspeed = maxspeed
    def show(self,x):
        print(x)
        print(f" the color of the car is {self.color} and the mileage is {self.mileage} with maxspeed {self.maxspeed}")
c = Car("black",13,120)
c.show(100)
print(c.color,c.mileage,c.maxspeed)
# Out:
# 100
#  the color of the car is black and the mileage is 13 with maxspeed 120
# black 13 120

# %% [markdown]
# ### Object-:
# While the class is the blueprint, an instance is an object that is built from a class and contains real data.
#
# The object is an entity that has state and behaviour.
#
# When we define a class only the description or a blueprint of the object is created. There is no memory allocation until we create its object.
#
# The objector instance contains real data or information.
#
# Instantiation is nothing but creating a new object/instance of a class
#
#
# ## object has data and behaviour , and its blueprint is created by class
# ### how to create an object-:
# instace_variable/object_variable = class_name()

# %%
class my_first_class:
    a = 10
    b = 20

# %%
obj = my_first_class()

# %%
print(obj.a)
print(obj.b)
# Out:
# 10
# 20

# %% [markdown]
# ### Type of variables inside class and object-:

# %% [markdown]
# 1. local variable : Local variables are those variables which are declared inside a function (first time). These variables can only be used inside a function. You can not use/access them outside that function.
# 2. class variable : Class variable are those variables that are declared inside a class with the class name. these variables can be access inside or outside a class using class name.
#
# eg : college name for student details, bank ifsc / bank name for customers,
# 3. Instance Variable:a variable declared inside a class or outside the class. They are also called the variable of object. Since they are object variable so they will be accessed using object name.We can access instance anywhere inside or outside the class.If you have created constructor then you will access the instance variable with self parameter inside the class and using instance name outside the class.

# %% [markdown]
# # In python everything is object
#  ### variable is also object.

# %%
## what are these?


list
tuple
float
int
# Out:
# int

# %%
type(list())
# Out:
# list

# %%
l=list() ## here l  is object list()is class (this act as blueprint wjich tells how object looks and behaves)

# %%
l=[1,2,3,4]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
s1.

# %%
#dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### Constructor

# %% [markdown]
# ### Constructor in python-:
# Constructor is a special function/magic function.
#
# Python has a special name of the constructor which is __init__. unlile in other languages like jave (where constructor name is same as clas name)
#
#
# __init__ is a method which is immediately and automatically called after an instance has been created. This name is fixed and it is not possible to choose another name. __init__ is one of the so-called magic methods, we will get to know it with some more details later. The __init__ method is used to initialize an instance.
#
# #### constructor is special or magic mathod means it starts with __
#
# thses types of methods are in built u can not create it own
#
# property of magic method:
#
# - We can not call it with object
# - They are automatically called.
#
#
#
#
#  constructor declaration:
# def __init__(self):
# ### body of the constructor
# Note-: we create constructor to initialize our instance variables inside a class.
# Constructor can take any number of parameters. The first parameter is the copy of the name of instance/object inside the class (it means constructors first variable is nothing but just a name that is another reference of your object).
#
# ### Self Parameter-:
# It is the first parameter of any constructor. You can give it any name but this will be the variable using which you can access of the instance variables inside a class. Because self is just a copy of your instance variable.
#
# #### Note: The self parameter is a reference to the current instance of the class, and is used to access variables that belong to the class.
#
# #### Types of constructors :
#
#
# • default constructor: The default constructor is simple constructor which doesn’t accept any arguments. If you did not create any constructor in your program it will automatically create by the interpreter.
#
# Syntax-: def __init__():
#
# • parameterized constructor: constructor with parameters is known as parameterized constructor. The parameterized constructor takes its first argument as a reference to the instance being constructed known as self and the rest of the arguments are provided by the programmer.
#
# Note -: you cannot overload the constructor in python. If you try, it will automatically follow python override property.

# %% [markdown]
# ### What is the utility of constructor???
#
#
# ### for intialization purpose , configuaration task, database connectivity that user can not control it.
#
# ### to give that piece of code for which we don't want to give control/access to user.

# %% [markdown]
# ### Note
# - self should be a first parameter Inside constructor
#    1. def __init__(self):
# - self should  be first inside instance methods
#     2. def __init__(self):

# %%
class Bank:
    def __init__(self):
        self.balance=10000
        self.withdrawl=0
        self.deposit=0
        print("welcome to bank\n 1: withdrawl \n 2: depsoit \n 3: check balance \n")
        ch=input("enter your choice")
        if ch=="1":
            self.withdrawl1()
        elif ch=="2":
            self.deposit1()
        elif ch=="3":
            self.check_balance()
        else:
            print("invalid choice")
    def withdrawl1(self):
        amount=int(input("enter the amount to be drawn"))
        if self.balance<amount:
            print("balanve is insuffiecient")
        else:
            self.balance=self.balance-amount
            print("sucessfully withdrawl")
            self.check_balance()
    def deposit1(self):
        amount=int(input("enter the amount to be deposited"))
        self.balance=self.balance+amount
        self.check_balance()
    def check_balance(self):
        print(self.balance)

# %%
icici=Bank()
# Out:
# welcome to bank\ 1: withdrawl
#  2: depsoit
#  3: check balance
#
# enter your choice1
# enter the amount to be drawn12000
# balanve is insuffiecient

# %%
hdfc=Bank()
# Out:
# welcome to bank
#  1: withdrawl
#  2: depsoit
#  3: check balance
#
# enter your choice2
# enter the amount to be deposited20000
# 30000

# %%
pnb=Bank()
# Out:
# welcome to ATM
#
#  1: CHECK BALANCE
#  2: WITHDRAWL
#  3: DEPOSIT
# enter your choice1
# balance is  10000

# %%
pnb=Bank()
# Out:
# welcome to ATM
#
#  1: CHECK BALANCE
#  2: WITHDRAWL
#  3: DEPOSIT
# enter your choice2
# enter the amount to be withdrawl4000
#  WITHDRAWAL done
# would you check balance press
#  1: yes
#  else 0
# enter your choice1
# balance is  6000

# %%
pnb.deposit()
# Out:
# enter the amount to be depsoited2000
# amount deposited
# would you check balance press
#  1: yes
#  else 0
# enter your choice1
# balance is  8000

# %% [markdown]
# ### understanding self :  why every methods use self as parameter?
#
# here, self means current object

# %%
class Student:  ## class name pascalname
    studentsclass="A"
    def __init__(self,name,age): ### constructor magic  methods 
        self.name=name   ### instance variable
        self.age=age     ### instamce variable
        print(id(self))
    def get_age(self):## methods name should be in snake case
        print(self.age)
s1=Student("priya",45)
s2=Student("riya",41)
print(id(s1))
print(id(s2))
# Out:
# 2009466373648
# 2009466373504
# 2009466373648
# 2009466373504

# %% [markdown]
# #### above output indicates that s1 is self : slef means current object with which you are working with it.
# ### why self is associated with methods in order to diiferentiate to which object methods and variables are accessed.
#
#
# in class has only two things data and behaviour object can access the data and behaviour . nobody can access it
#
# since we know methods in class can not talk directly  with other methods means deposit function can access create_pin method using self.create_pin means using object

# %% [markdown]
# ### Encapsulation
#
#
#
# ### Encapsulation: wrapping of data into single unit called class.
#
#
# This property hides unnecessary details and makes it easier to manage the program
# structure. Each object’s implementation and state are hidden behind well-defined
# boundaries and that provides a clean and simple interface for working with them. One way
# to accomplish this is by making the data private.
#
#
# Encapsulation in python is a process of wrapping code and data together into a single unit. which means it is a way to ensure security. Basically **it hides the variable from the access outsider's by using single_(underscore) before the variable name to make it protected and __(double underscore) before the variable to make it private**

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![encapsu;ation.JPG](attachment:encapsu;ation.JPG)

# %% [markdown]
# ![encapsulation1.JPG](attachment:encapsulation1.JPG)

# %% [markdown]
# ![public1.JPG](attachment:public1.JPG)

# %% [markdown]
# ![public2.JPG](attachment:public2.JPG)

# %% [markdown]
# ![public3.JPG](attachment:public3.JPG)

# %%
class ola:
    def __init__(self,loc,t):
        self.location=loc
        self.driver_no=123234494043
        self.__driver_commission=10000  ## DATA HIDING
        self.type=t
    def details(self):
        print("the car type is",self.type)
        print("the location is",self.location)
        print("the driver number is ",self.driver_no)
        print("the driver commison  is ",self.__driver_commission)

# %%
t1=input("enter the car type")
l=input("enter the location")
ola1=ola(l,t1)
# Out:
# enter the car typesedan
# enter the locationjkdj

# %%
ola1.details()
# Out:
# the car type is sedan
# the location is jkdj
# the driver number is  123234494043
# the driver commison  is  10000

# %%
ola1._ola__driver_commission ## name mangling
# Out:
# 10000

# %%
t1=input("enter the car type")
l=input("enter the location")
ola2=ola(l,t1)
# Out:
# enter the car typedesire
# enter the locationrajouri gardern

# %%
ola2.details()
# Out:
# the car type is desire
# the location is rajouri gardern
# the driver number is  123234494043

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 ola1=ola()
#
# TypeError: __init__() missing 2 required positional arguments: 'loc' and 't'

# %%
ola1=Ola()

# %%
ola1.book="chandigarh" ## object can access it or update it

# %%
ola1.details()
# Out:
# 500
# chandigarh
# 978111109

# %%
ola1.__carprice  ## can not access it so we secure it
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 ola1.__carprice
#
# AttributeError: 'Ola' object has no attribute '__carprice'

# %%
ola1._Ola__carprice  ##  name mangling  : so python is not 100% security
# Out:
# 500

# %%
class Car:
    def __init__(self,name,milleage,color):
        self._name=name #Protected Variable
        self.milleage=milleage #Public Variable
        self.__color=color #Private Vaiable
        
    def description(self):
        return f'this car name is {self._name} and its color is {self.__color} and gives a milleage of {self.milleage}'
    
    def max_speed(self,speed):
        return f" its  maximum speed is{speed}"
    
    
obj1=Car('BMW',12,'grey')
print(obj1.description())
print(obj1.max_speed(300))

# Accessing the protected and public variable outside of the class
print(obj1._name)
print(obj1.milleage)
print(obj1._Car__color)  ## (mangled name )not truely 100% private since we can access it indirectly. beacuse pyhton is designed for adults.
print(obj1.__color)
# Out:
# this car name is BMW and its color is grey and gives a milleage of 12
#  its  maximum speed is300
# BMW
# 12
# grey
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 22>()
#      20 print(obj1.milleage)
#      21 print(obj1._Car__color)  ## (mangled name )not truely 100% private since we can access it indirectly. beacuse pyhton is designed for adults.
# ---> 22 print(obj1.__color)
#
# AttributeError: 'Car' object has no attribute '__color'

# %%
### Name Mangling is the mechanism to acces the Private variable from outside of the class

# %% [markdown]
# Q1. Construct a class car with attributes max speed and mileage
# also define a method description which prints the name max speed and mileage
# of cars . and one more method named as sitting capacity and u need to print the sitting capacity of the car

# %%
'''Construct a class with attributes max speed and mileage also define a method description which prints \
the name max speed and mileage of the cars adn one more method named as sitting capacity and u need  to print the sitting \
capacity of the car'''

class Car:
    def __init__(self,maxspeed1,mileage1):
        self.maxspeed=maxspeed1
        self.mileage=mileage1
    def car_details(self):
        print(f"the maxspeed of the car is {self.maxspeed} and the mileage is {self.mileage}")
    def sitting_capacity(self):
        capacity=5
        print(f"sitting capacity of car is {capacity}")
c=Car(120,13)
print(c)
c.car_details()
c.sitting_capacity()
print(c.maxspeed)

# %%
class car:
    def __init__(self,maxspeed,mileage):
        self.maxspeed = maxspeed
        self.mileage = mileage
        
    def description(self):
        print("the car speed is ",self.maxspeed,"and the mileage is ",self.mileage)

c = car(320,13)
c.description()
# Out:
# the car speed is  320 and the mileage is  13

# %% [markdown]
# ### 2.  Inheritance
#
#
#
#
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
# Parent class is the class being inherited from, also called base class.
# Child class is the class that inherits from another class, also called derived class.

# %% [markdown]
# ![inheritance.JPG](attachment:inheritance.JPG)

# %% [markdown]
# ![inheritance2.JPG](attachment:inheritance2.JPG)

# %% [markdown]
# ![Capture.1PNG.PNG](attachment:Capture.1PNG.PNG)

# %% [markdown]
# In this above diagram we can see that Class B inherits the Class AIn this above diagram we can see that Class B inherits the Class A
#
# It also allows programmer to write better code. Using inheritance you can inherit all access data fields and methods, plus you can add your own methods and fields, thus inheritance provide a way to organize code, rather than rewriting it from scratch.

# %% [markdown]
# ### What child inherits ?
#
# - Data members/data methods
# - constructor
# - protected memebers
#
# ### What child not inherits ?
#
# - private members

# %%
class Vehicle: #Parent class or Base class
    def __init__(self,name,milleage):
        self.name=name
        self.milleage=milleage
        
    def description(self):
        return f'the milleage of the {self.name} is {self.milleage}'
        
class Car(Vehicle): # Child class or Derived class
    def max_speed(self,speed):
        return f'the maximum speed of this car is {speed}'
    
class Bus(Vehicle):
    def show(self):
        return 'this is an description of Bus class'
    
class Train(Car):
    pass

obj1=Car('creta',12) # Making object of an Child class 
print(obj1.description()) # here it inherits the properties of Parent class
print(obj1.max_speed(300)) # it is the method of Child class

print()

obj1=Bus('Q7',15)
print(obj1.description())
print(obj1.show())

print()

obj1=Train('Indian Railway',8)
print(obj1.description())
# Out:
# the milleage of the creta is 12
# the maximum speed of this car is 300
#
# the milleage of the Q7 is 15
# this is an description of Bus class
#
# the milleage of the Indian Railway is 8

# %% [markdown]
# ## trainer/student  example

# %%
class User:
    def attendance(self):
        print("attendance")
    def login(self):
        print("login successfully")
    def registration(self):
        print("registration")
class Student(User):
    def enroll(self):
        print("enrolled")
    def review(self):
        print("review")
class Trainer(User):
    def teaching(self):
        print("teaching done")

# %%
st1=Student()

# %%
st1.enroll()
# Out:
# enrolled

# %%
st1.attendance()
# Out:
# attendance

# %%
t1=Trainer()

# %%
t1.attendance

# %%
## single 
class Student:
    def __init__(self,name,cname,fees,grade):
        self.name=name
        self.cname=cname
        self.grade=grade
        self.__fees=fees
class Trainer(Student):
    #def __init__(self,name,cname,fees,grade):
        #super().__init__(name,cname,fees,grade)
        self._salary="20k"
    def get_details(self):
        print("student name",self.name)
        print("student course name",self.cname)
        print("student grade",self.grade)
        
        #print("student fees",self.__fees)
class Admin(Trainer):
    pass

# %%
class Trainer():
    def __init__(self,name,cname,grade,ex):
        self._salary="20k"
        self.name=name
        self.cname=cname
        self.grade=grade
        self.__experience=ex
    
class Admin(Trainer):
    def get_details(self):
        print("student name",self.name)
        print("student course name",self.cname)
        print("student grade",self.grade)
        print("trainer salary",self._salary)
        print("trainer experince",self.__experience)

# %%
a=Admin("ritu","python","a",5)

# %%
a.cname
# Out:
# 'python'

# %%
a.get_details()
# Out:
# student name ritu
# student course name python
# student grade a
# trainer salary 20k
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [206], in <cell line: 1>()
# ----> 1 a.get_details()
#
# Input In [204], in Admin.get_details(self)
#      13 print("student grade",self.grade)
#      14 print("trainer salary",self._salary)
# ---> 15 print("trainer experince",self.__experience)
#
# AttributeError: 'Admin' object has no attribute '_Admin__experience'

# %%
a=Admin("ritu","python",50,"a")

# %%
t1=Trainer("ritu","python",50,"a")

# %%
t1.get_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [168], in <cell line: 1>()
# ----> 1 t1.get_details()
#
# Input In [159], in Trainer.get_details(self)
#      11 def get_details(self):
# ---> 12     print("student name",self.name)
#      13     print("student course name",self.cname)
#      14     print("student grade",self.grade)
#
# AttributeError: 'Trainer' object has no attribute 'name'

# %%
a._salary
# Out:
# '20k'

# %%
t1=Trainer("kawal","python",40000,"a")

# %%
t1.get_details()
# Out:
# student name kawal
# student course name python
# student grade a

# %%
class father:
    def __init__(self):
        self.property=2
    def profession(self):
        print("business man")
class son(father):
    def profession(self):
        super()
        print("engineer")
    def dancing(self):
        print("i love dancing")

# %%
s=son()

# %%
s.profession()
# Out:
# engineer

# %%
## single inheritance 
class User:
    def login(self):
        print("login")
    def register(self):
        print("register")
class Student(User):
    def enroll(self):
        print("enrolled")
    def review(self):
        print("reviewd")
St1=Student() ## create child class object
St1.login() ##  child class can inherit parent class method
St1.enroll() ##  child class object can access its own data/method
# Out:
# login
# enrolled

# %%
## single inheritance 
class User:
    def login(self):
        print("login")
    def register(self):
        print("register")
class Trainer(User):
    def training(self):
        print("give trainings")
t1=Trainer()
t1.login() ##  child class can inherit parent class method
t1.training()
# Out:
# login
# give trainings

# %% [markdown]
# ## hierarchical

# %%
class User:
    def login(self):
        print("login")
    def register(self):
        print("register")
class Student(User):

    def enroll(self):
        print("enrolled")
    def review(self):
        print("reviewd")
class Trainer(User):
    def training(self):
        print("give trainings")
s1=Student()
s1.enroll()
t1=Trainer()
t1.training()
# Out:
# enrolled
# give trainings

# %% [markdown]
# ### - private members can not access it in child class
# ## - protected members can inherit
# ## - parent class constructor inherited
#
# (### if child class has no its own constructor so base class' constructor automatically called.)

# %%
class Student():
    def __init__(self,fees,cname,name,grade):
        print("parent constructor")
        self.__fees=fees  ## private
        self.coursename=cname
        self.name=name
        self._assesmentgrade=grade ## protected memebers
    def enroll(self):
        print("enrolled")
    def review(self):
        print("reviewd")
class DataScienceTrainer(Student):
    def training(self):
        print("give trainings")
    def get_details(self):
        print(self.name,"has details as ::")
        print(self._assesmentgrade)  ## can access protected members
        print(self.coursename) 
        #print(self.fees)  ## can not acess private members
d1=DataScienceTrainer(50000,"da","heena","A")  ## calling child class constructor  but child class constructor is not present so call parent class constructor
d1.get_details()
# Out:
# parent constructor
# heena has details as ::
# A
# da

# %% [markdown]
# ### passing details of student from user

# %%
for i in range(1,6):
    n=input("enter the student name")
    g=input("enter the grade")
    c=input("enter the course ")
    f=input("enter the fees")
    d=DataScienceTrainer(f,c,n,g)
    d.get_details()

# %% [markdown]
# ### use of super ()
# Python also has a super() function that will make the child class inherit all the methods and properties from its parent. By using the super() function, you do not have to use the name of the parent element, it will automatically inherit the methods and properties from its parent.

# %% [markdown]
# ### call parent class constructor from child class  using super

# %%
class Student():
    def __init__(self,fees,cname,name,grade):
        self.__fees=fees  ## private
        self.coursename=cname
        self.name=name
        self._assesmentgrade=grade ## protected memebers
    def enroll(self):
        print("enrolled")
    def review(self):
        print("reviewd")
class DataScienceTrainer(Student):
    def __init__(self,fees,cname,name,grade,nstudents):
        #super().__init__(fees,cname,name,grade)
        self.noofstudents=nstudents
    def training(self):
        print("give trainings")
    def get_details(self):
        print(self.name,"has details as ::")
        print(self.coursename)
        #print(self.fees)  ## can not acess private members
    def student_strength(self):
        print("ds trainer has ",self.noofstudents,"students")
d1=DataScienceTrainer(5000,"da","jai","a",100)  ## calling child class constructor  but child class constructor is not present so call parent class constructor
#d1.get_details()
d1.student_strength()
# Out:
# ds trainer has  100 students

# %% [markdown]
# ### method overriding :  call parent class method using super

# %%
class Parent:
    def details(self):
        age=50
        city="delhi"
        print("parent lives in",city,"and his age is",age)
    def profession(self):  
        print("doctor")
class Son(Parent):
    def profession(self):  ## over riding
        #super().profession()  ## calling parent class method 
        print("engineer") 
s1=Son()
#s1.details()
s1.profession() ## calling child class method
# Out:
# engineer

# %%
class Person:
    
    def __init__(self, fname,lname):
        self.firstname = fname
        self.lastname = lname
    
    def printname(self):
        print(self.firstname,self.lastname)
        
class Employee(Person):
    def __init__(self,fname,lname):
        
        self.fname = fname
        self.lname = lname
        
        Person.__init__(self,fname,lname)
        
obj = Employee("Sana","maha")
obj.printname()
# Out:
# Sana maha

# %%
class Phone:
    def __init__(self,price,brand,camera):
        self.price=price
        self.brand=brand
        self.camera=camera
        print(self.price)
        print(self.brand)
        print(self.camera)
    def buy(self):
        print("buying phone")
class SmartPhone(Phone):
    def buy(self):
        print("buying smartphone")
        super().buy()
p1=SmartPhone(30000,"samsung",13)
p1.buy()
# Out:
# 30000
# samsung
# 13
# buying smartphone
# buying phone

# %% [markdown]
# ### Types of inheritance

# %% [markdown]
# ![types-of-inheritance1.png](attachment:types-of-inheritance1.png)

# %% [markdown]
# ## MULTIPLE INERITANCE

# %%
class Phone:
        def buy(self):
            print("buying phone")
class SmartPhone():
    def buy(self):
        print("buying smartphone")
class Smartwatch(SmartPhone,Phone): ### smartwatch inherits buy method from both parent but method is same so based on MRO(METHOD RESOLUTION ORDER ) METHOD OF THAT CLASS IS OVER RIDDEN 
    pass
s=Smartwatch()
s.buy()
# Out:
# buying smartphone

# %% [markdown]
# ### Polymorphism
# This is a Greek word. If we break the term Polymorphism, we get “poly”-many and “morph”-forms. So, Polymorphism means having many forms. In OOP it refers to the functions having the same names but carrying different functionalities

# %% [markdown]
# ### Example
# - A Teacher can take a form of Sport Teacher or Language Teacher and in both the forms it has the same functionality Teach, but the implementation of Teach varies in both the objects.

# %% [markdown]
# ![poly.JPG](attachment:poly.JPG)

# %%
### overlaoding not possible IN PYTHON
class Geometry:
    def area(self,radius):
        return 3.14*radius*radius
    def area(self,l,b):
        return l*b
shape=Geometry()
shape.area(4,6)
shape.area(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [214], in <cell line: 9>()
#       7 shape=Geometry()
#       8 shape.area(4,6)
# ----> 9 shape.area(5)
#
# TypeError: area() missing 1 required positional argument: 'b'

# %% [markdown]
# ### overriding

# %%
class Audi:
    def description(self):
        return 'this is an description of Audi class'
class BMW:
    def description(self):
        return 'This is an description of BMW class'
obj_Audi=Audi()
obj_BMW=BMW()
# Polymorphism
for i in (obj_Audi,obj_BMW):
    print(i.description())
# Out:
# this is an description of Audi class
# This is an description of BMW class

# %% [markdown]
# ###  Data abstraction
#
#
# ![Capture3.PNG](attachment:Capture3.PNG)
# We use Abstraction for hiding the internal details or implementations of a function and showing its functionalities only. This is similar to the way you know how to drive a car without knowing the background mechanism. Or you know how to turn on or off a light using a switch but you don’t know what is happening behind the socket.
#
#
#
# Abstraction in python is defined as a process of handling complexity by hiding unnecessary details from the user. which means we hides the internal functionality of the function from the users or we can say that we just hides the class from abstraction method

# %%
from abc import ABC, abstractmethod
class Animal(ABC): ## absttact class atleat one abstract method
    def sleep(self): ## concrete/normal method
        print("i am going to sleep in while")
    @abstractmethod   # decorator
    def sound(self):  ## abstract method  whose implementation needs to be given by child class.
        pass
class Dog(Animal):
    def sound(self):   ## implementation
        print("i can bark")

# %%
a=Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [216], in <cell line: 1>()
# ----> 1 a=Animal()
#
# TypeError: Can't instantiate abstract class Animal with abstract method sound

# %%
d1=Dog()
d1.sound()
# Out:
# i can bark

# %%
d=Dog()

# %%
from abc import ABC, abstractmethod # Here Car is the abstract class that inherits from the ABC class from the abc module
class Car(ABC):
    def __init__(self,name):
        self.name=name
    @abstractmethod   # abstract method price
    def description(self,price):
        pass
    
class Audi(Car):  
    def description(self,price):  ## CHILD CLASS NEED TO GIVE IMPLEMENTATION OF PARENT
        return f'the car name is {self.name} and its price is{price} '
    
obj1=Audi('BMW')
print(obj1.description(5000000))
# Out:
# the car name is BMW and its price is5000000

# %%
Car()  ## can not instatiate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 Car()
#
# TypeError: Can't instantiate abstract class Car with abstract method description

# %%
from abc import ABC, abstractmethod

class Car(ABC):
    def __init__(self,name,color,maxspeed):
        self._name = name  #protected variable
        self.__color = color 
        self.maxspeed = maxspeed
    def show(self):
        print(f"the {self._name} is of {self.__color} and has maxspeed of {self.maxspeed}")

    @abstractmethod
    def price(self,x):
        print("this method is hidden cannot open or use this",x)
# c1 = Car("Honda","black",340)
# c1.show()
class Sedan1(Car):
    def price1(self):
            print("this is price of Sedan ",1000000)

obj1 = Sedan("Honda City","black",340)
obj1.show()
print(obj1.maxspeed)
print(obj1._name)
obj1._Car__color
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-0b67bf1d3034> in <module>
#      18             print("this is price of Sedan ",1000000)
#      19
# ---> 20 obj1 = Sedan1("Honda City","black",340)
#      21 obj1.show()
#      22 print(obj1.maxspeed)
#
# TypeError: Can't instantiate abstract class Sedan1 with abstract methods price

# %%
from abc import ABC, abstractmethod

class Car(ABC):
    def __init__(self,name):
        self.name = name
    def show(self):
        print("this is a show")

    @abstractmethod
    def price(self,x):
        print("the method is hidden")
# c = Car("Honda City")
# c.show()
class new(Car):
    def price(self,x):
        print(f"the price of the car is {x} crores")
ob1 = new('Lamborgini')
ob1.show()
ob1.price(2.6)
ob1.name
# Out:
# this is a show
# the price of the car is 2.6 crores
# 'Lamborgini'

# %% [markdown]
# Q1. Create a Vehicle class with max_speed and mileage instance attributes
#
# Q2.Create a Vehicle class without any variables and methods
#
# Q3.Create a child class Bus that will inherit all of the variables and methods of the Vehicle class
#
# Q4.Class Inheritance
# Given:Create a Bus class that inherits from the Vehicle class.
# Give the capacity argument of Bus.seating_capacity() a default value of 50.

# %% [markdown]
# WAC shape take the input from the user regarding the shape and then make a method called area and take the sides input from the user and then compute the arra of the shape

# %%
class Bus(vehicle):
    def seating_capacity(self,x = 50):
        print(f"the sitting capacity of the bus is {x}")
obj1 = Bus()
obj1.seating_capacity()
# Out:
# the sitting capacity of the bus is 50

# %% [markdown]
# Define a Book class with the following attributes: Title, Author (Full name), Price. Define a constructor used to initialize the attributes of the method with values entered by the user.
# Set the View() method to display information for the current book.
# Write a program to testing the Book class.

# %%
class book:
    def __init__(self,Title,Author,Price):
        self.Title = input("title: ")
        self.Author = input("Author: ")
        self.Price = int(input("price: "))
                         
    def View(self):
        print(f"The {self.Title} of the book authored by Mr. {self.Author} and the price is {self.Price}")
book = book("a","b",2)
book.View()
# Out:
# title: python
# Author: bala
# price: 900
# The python of the book authored by Mr. bala and the price is 900

# %% [markdown]
# **Q6.Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.** <br/>
# $\;\;\;\;\;$ Create a constructor with parameters: accountNumber, name, balance. <br/>
# $\;\;\;\;\;$ Create a Deposit() method which manages the deposit actions. <br/>
# $\;\;\;\;\;$ Create a Withdrawal() method which manages withdrawals actions. <br/>
# $\;\;\;\;\;$ Create a bankFees() method to apply the bank fees with a percentage of 5% of the balance account. <br/>
# $\;\;\;\;\;$ Create a display()**

# %%
class BankAcc:
    def __init__(self,accno,name,balance):
        self.accno = accno
        self.name = name
        self.balance = balance
    def Deposit(self):
        D = int(input("Enter the amount to be deposited :"))
        balance = self.balance+D
        print("balance is :",balance)
    def Withdrawal(self):
        W = int(input("Enter the amount to be withdrawal :"))
        balance = self.balance-W
        print("balance is :",balance)
    def bankfees(self):
        bank_fee = self.balance*0.05
        print(bank_fee)
        
acc = BankAcc(123456,"dinesh",50000)
acc.Deposit()
acc.Withdrawal()
# Out:
# Enter the amount to be deposited :4
# balance is : 50004
# Enter the amount to be withdrawal :5
# balance is : 49995
